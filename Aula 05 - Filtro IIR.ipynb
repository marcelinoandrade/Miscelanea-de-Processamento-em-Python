# %%
from scipy import signal
import numpy as np
import pandas as pd
import math as mt
import matplotlib.pyplot as plt

# %%
wsz=pd.DataFrame([w,s,z]).transpose()
wsz.columns=[['w','s','z']]
wsz.head(3)
# Out:
#                          w                    s  \
# 0                       0j                   0j
# 1  (0.4487989505128276+0j)  0.4487989505128276j
# 2  (0.8975979010256552+0j)  0.8975979010256552j
#
#                                           z
# 0                                    (1+0j)
# 1  (0.9009688679024191+0.4338837391175581j)
# 2  (0.6234898018587336+0.7818314824680298j)

# %%
N=7
w = np.arange(0, N-1, np.pi/N)

ts=1 #seg
s=complex(0,1)*w #  Plano S 
z=np.exp(s*ts) # Plano Z 

fig = plt.subplots(figsize=(8,3))
ax1=plt.subplot(121)  
ax1.plot(np.real(s),np.imag(s),'o')
ax1.set_ylabel('Eixo Imaginário')
ax1.set_xlabel('Eixo Real')
ax1.set_title('Plano s')
ax1.grid()

ax2=plt.subplot(122,projection='polar')  
ax2.plot(w,abs(z),'o')
ax2.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
ax2.set_title("Plano z", va='bottom')
# Out:
# Text(0.5, 1.05, 'Plano z')

# %%
N=7
w = np.arange(0, N-1, np.pi/N)

ts=1 #seg
s=complex(0,1)*w #  Plano S 
z=(1+s)/(1-s) # Plano Z 

fig = plt.subplots(figsize=(8,3))
ax1=plt.subplot(121)  
ax1.plot(np.real(s),np.imag(s),'o')
ax1.set_ylabel('Eixo Imaginário')
ax1.set_xlabel('Eixo Real')
ax1.set_title('Plano s')
ax1.grid()

ax2=plt.subplot(122,projection='polar')  
ax2.plot(w,abs(z),'o')
ax2.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
ax2.set_title("Plano z", va='bottom')
# Out:
# Text(0.5, 1.05, 'Plano z')

# %%
#Mapeando sigma
import pandas as pd
sigma = np.arange(-1, 1.5, 0.5)
z=np.exp(sigma)
result=pd.DataFrame([sigma, z]).transpose()
result.columns=[['Sigma','Módulo de Z']]
result
# Out:
#    Sigma  Módulo de Z
# 0   -1.0     0.367879
# 1   -0.5     0.606531
# 2    0.0     1.000000
# 3    0.5     1.648721
# 4    1.0     2.718282

# %%
N=7
w = np.arange(0, N-1, np.pi/N)

ts=10 #seg
s=complex(0,1)*w #  Plano S 
z=(1+s)/(1-s) # Plano Z 

fig = plt.subplots(figsize=(8,3))
ax1=plt.subplot(121)  
ax1.plot(np.real(s),np.imag(s),'o')
ax1.set_ylabel('Eixo Imaginário')
ax1.set_xlabel('Eixo Real')
ax1.set_title('Plano s')
ax1.grid()

ax2=plt.subplot(122,projection='polar')  
ax2.plot(w,abs(z),'o')
ax2.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
ax2.set_title("Plano z", va='bottom')
# Out:
# Text(0.5, 1.05, 'Plano z')

# %%
import pandas as pd
sigma = np.arange(-1, 1.5, 0.5)
z=(1+sigma)/(1-sigma)
result=pd.DataFrame([sigma, z]).transpose()
result.columns=[['Sigma','Módulo de Z']]
result
# Out:
# /home/mrclnndrd/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Sigma  Módulo de Z
# 0   -1.0     0.000000
# 1   -0.5     0.333333
# 2    0.0     1.000000
# 3    0.5     3.000000
# 4    1.0          inf

# %%
N=12
w = np.arange(0, N-1, np.pi/N)
Omega=2*np.arctan(w)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

plt.plot(w,Omega)

plt.xlabel(r'$\omega$',fontsize=30)
plt.ylabel(r'$\Omega$',fontsize=30)
plt.title(r'$\Omega = \tan^{-1}(\omega)$',fontsize=30)


plt.title(r"\TeX\ is Number "
          r"$\displaystyle\sum_{n=1}^\infty\frac{-e^{i\pi}}{2^n}$!",
          fontsize=16, color='blue')
# Out:
# Text(0.5, 1.0, '\\TeX\\ is Number $\\displaystyle\\sum_{n=1}^\\infty\\frac{-e^{i\\pi}}{2^n}$!')

# %%
mu=0.1
gama=0.1
alpha=(1-mu)/mu
beta=gama/(1-gama)
wp=10 #rad/s
ws=30
N=round(1/2*(np.log(alpha/beta))/np.log(ws/wp),2)
N
# Out:
# 2.0

# %%
wc=round(ws/(alpha)**(1/(2*N)),2)
wc
# Out:
# 17.32

# %%
wc=round(wp/(beta)**(1/(2*N)),2)
wc
# Out:
# 17.32

# %%
coeff = [1/(wc**4),0,0,0,1]
rootcoeff=np.roots(coeff)
rootcoeff
# Out:
# array([-12.24708945+12.24708945j, -12.24708945-12.24708945j,
#         12.24708945+12.24708945j,  12.24708945-12.24708945j])

# %%
fig = plt.subplots(figsize=(2,2))
ax1=plt.subplot(111)  
ax1.plot(np.real(rootcoeff),np.imag(rootcoeff),'o')
ax1.set_ylabel('Eixo Imaginário')
ax1.set_xlabel('Eixo Real')
ax1.set_title('Plano s')
ax1.grid()
plt.savefig('Aula5.jpeg',dpi=300)

# %%
w=np.array(range(0,500))/10
s=complex(0,1)*w
Hs=300/(s**2+24.5*s+300)



fig = plt.subplots(figsize=(5,5))

ax1=plt.subplot(1, 1, 1)  
ax1.plot(w, abs(Hs)**2)
ax1.set_ylabel('Amplitude')
ax1.set_xlabel('Frequencia')
ax1.set_title('Win')
ax1.grid()
plt.savefig('Aula5.jpeg',dpi=300)

# %%
Hw2=abs(Hs)**2
np.min(np.where(Hw2<1/(2**(1/2))))
# Out:
# 139

# %%
w[139]
# Out:
# 13.9

# %%
Hw=20*np.log(abs(Hs))
np.min(np.where(Hw<-3))
w[134]
# Out:
# 13.4

# %%
#Para corrigir o eixo das frequencias!!!!
fs=10
ts=1/fs
w=np.arange(0,np.pi,ts)

z=np.exp(-complex(0,1)*w)
tb=(2/ts)*(z-1)/(z+1)
Hz=300/(tb**2+24.5*tb+300)



fig = plt.subplots(figsize=(5,5))

ax1=plt.subplot(1, 1, 1)  
ax1.plot((1/np.pi)*w*fs/2, abs(Hz)**2)
ax1.set_ylabel('Amplitude')
ax1.set_xlabel('Frequencia')
ax1.set_title('Win')
ax1.grid()

# %%
#https://scipy-cookbook.readthedocs.io/items/ButterworthBandpass.html

from scipy.signal import butter, lfilter, freqz

def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y


def run():
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy.signal import freqz

# Sample rate and desired cutoff frequencies (in Hz).
fs = 5000.0
lowcut = 500.0
highcut = 1250.0

# Plot the frequency response for a few different orders.
plt.figure(1)
plt.clf()
for order in [3, 9, 15]:
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    w, h = freqz(b, a, worN=2000)
    plt.plot((fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)

    plt.plot([0, 0.5 * fs], [np.sqrt(0.5), np.sqrt(0.5)],'--', label='sqrt(0.5)')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Gain')
    plt.grid(True)
    plt.legend(loc='best')

    # Filter a noisy signal.
    T = 0.05
    nsamples = T * fs
    t = np.linspace(0, T, nsamples, endpoint=False)
    a = 0.02
    f0 = 600.0
    x = 0.1 * np.sin(2 * np.pi * 1.2 * np.sqrt(t))
    x += 0.01 * np.cos(2 * np.pi * 312 * t + 0.1)
    x += a * np.cos(2 * np.pi * f0 * t + .11)
    x += 0.03 * np.cos(2 * np.pi * 2000 * t)
    plt.figure(2)
    plt.clf()
    plt.plot(t, x, label='Noisy signal')

    y = butter_bandpass_filter(x, lowcut, highcut, fs, order=6)
    plt.plot(t, y, label='Filtered signal (%g Hz)' % f0)
    plt.xlabel('time (seconds)')
    plt.hlines([-a, a], 0, T, linestyles='--')
    plt.grid(True)
    plt.axis('tight')
    plt.legend(loc='upper left')

    plt.show()


run()
# Out:
# /home/mrclnndrd/anaconda3/envs/pyunb/lib/python3.6/site-packages/ipykernel_launcher.py:46: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
