# %%
from scipy import signal
import numpy as np
b = signal.firwin(80, 0.1, window=('kaiser', 8))
w, h = signal.freqz(b)

# %%
import matplotlib.pyplot as plt
fig = plt.subplots(figsize=(12,5))
plt.subplots_adjust(wspace=.5, hspace=.8)
ax1=plt.subplot(2, 1, 1)  
ax1.set_title('Digital filter frequency response')

ax1.plot(w, 20 * np.log10(abs(h)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.grid(which='both', axis='both')


ax2=plt.subplot(2, 1, 2)  
#ax2.grid(which='both', axis='both')
angles = np.unwrap(np.angle(h))
ax2.plot(w, angles, 'g')
ax2.set_ylabel('Angle (radians)', color='g')
ax2.grid()
ax2.axis('tight')
ax2.set_xlabel('Frequency [rad/sample]')
#ax2.show()
# Out:
# Text(0.5, 0, 'Frequency [rad/sample]')

# %%
[a[0], a[1], a[2]]
#
# Out:
# [1.0, 70.71067811865476, 2499.9999999999995]

# %%
b, a = signal.butter(2, 50, 'low', analog=True)
w, h = signal.freqs(b, a)
fig = plt.subplots(figsize=(10,2))
plt.plot(w, 20 * np.log10(abs(h)))
plt.xscale('log')
plt.title('Butterworth filter frequency response')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')
#plt.margins(0, 0.1)
plt.grid(which='both', axis='both')
plt.axvline(100, color='green') # cutoff frequency
plt.show()

# %%
w=np.array(range(-200,200))*0.11

tau=1
Ho=2*np.exp(-1j*w*tau/2)*np.sin(w*tau/2)/w

import math
fig = plt.subplots(figsize=(12,5))
plt.subplots_adjust(wspace=.5, hspace=.8)
ax1=plt.subplot(2, 1, 1)  
ax1.set_title('Digital filter frequency response')
 
#ax1.plot(np.array(w)/(2*math.pi), 20 * np.log10(abs(Ho)), 'b')
#ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.plot(np.array(w)/(2*math.pi), np.abs(Ho), 'b')
ax1.set_ylabel('Amplitude [Linear]', color='k')

ax1.set_xlabel('Frequencia [Hz]', color='k')
ax1.grid(which='both', axis='both')
# Out:
# /home/mrclnndrd/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.

# %%
w=np.array(range(-200,200))*1

tau=0.1
Ho=w*tau/(2*np.sin(w*tau/2))     #              2*np.exp(-1j*w*tau/2)*np.sin(w*tau/2)/w

import math
fig = plt.subplots(figsize=(12,5))
plt.subplots_adjust(wspace=.5, hspace=.8)
ax1=plt.subplot(2, 1, 1)  
ax1.set_title('Digital filter frequency response')
 
ax1.plot(np.array(w)/(2*math.pi), 20 * np.log10(abs(Ho)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
#ax1.plot(np.array(w)/(2*math.pi), np.abs(Ho), 'b')
#ax1.set_ylabel('Amplitude [Linear]', color='k')

ax1.set_xlabel('Frequencia [Hz]', color='k')
ax1.grid(which='both', axis='both')
# Out:
# /home/mrclnndrd/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.
